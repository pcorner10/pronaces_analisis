# %% [markdown]
# # Proceso para generar la base de datos de suelo

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob, os

# %% [markdown]
# ## files

# %%
files_suelos = glob.glob("data/suelo/*.xlsx")
files_suelos
# Out:
# ['data/suelo\\Armería SUELO.xlsx',
#  'data/suelo\\Formato de Campo suelo-Colima.xlsx',
#  'data/suelo\\Formato de Campo suelo-Formato base.xlsx',
#  'data/suelo\\Formato de Campo suelo-Nogueras-Minatitlán.xlsx',
#  'data/suelo\\Formato de Campo suelo-Quesería.xlsx',
#  'data/suelo\\Formato de Campo suelo-Villa de Álvarez.xlsx',
#  'data/suelo\\Manzanillo Dr Roberto (Muestras Suelo).xlsx',
#  'data/suelo\\Suelo Cuauhtemoc Alzada.xlsx',
#  'data/suelo\\Suelo Manzanillo.xlsx',
#  'data/suelo\\Tecomán Suelo.xlsx']

# %%
columns_to_right = [
       'Clave del Proyecto:',
       'Localidad, Mpio. y Edo.:',
       
       'Fecha:',
       'Hora de inicio (hh:mm): ',
       'Hora de término (hh:mm):',
       
       'Tipo de muestreo:',
       'Tipo de muestra:',
       'Refrigeración:',
       
       'UTM hor.:',
       'UTM ver.:',
       'msnm:',
       
       'Condiciones climáticas:',
       'Tipo de vegetación:',
       'Forma del terreno:',
       'Tipo de suelo:',
       'Paisaje:',
       
       'Uso de suelo:',
       'Edificación o infraestructura:',
       'Inclinación:',
       'Evidencia de erosión:',
       'Material parental:',
       ]

columns_to_down = [
       'Clave de la muestra:'
]

# %%
def readFormato(fileExcel, full_df):
  """_summary_: Lee el formato de la base de datos de suelos alojados en hojas dentro de un archivo excel y lo retorna en un dataframe
  """
  # load excel file and get sheet names
  xls = pd.ExcelFile(fileExcel)
  sheet_names = xls.sheet_names
  
  #full_df = pd.DataFrame()
  
  for sheet in sheet_names:
    df = pd.read_excel(fileExcel, sheet_name=sheet)
    df.dropna(axis=0, how='all', inplace=True)
    
    # drop columns with all NaN values
    df.dropna(axis=1, how='all', inplace=True)
    
    
    diccionario_dataframe = {}
    ubicacion = 0
    contador = 0
    for i, row in df.iterrows():
      

      # iterate over elements in row
      for j, element in enumerate(row):
        if element == 'Clave de la muestra:':
          ubicacion = j
          contador = 1
          continue
        
        if j == ubicacion and contador == 1: 
          diccionario_dataframe['Clave de la muestra:'] = element
          contador = 2
        
        # check if element is in columns_to_check
        if element in columns_to_right:
          # get column name
          col_name = element
          # get value in the next column two columns
          val = row[j+1:j+4]
          # drop NaN values
          val = val.dropna()
          
          # check if len of val different than 0 and not in columns_to_right
          if len(val) != 0 and val[0] not in columns_to_right:
            diccionario_dataframe[col_name] = val.values[0]
    full_df = pd.concat([full_df, pd.DataFrame(diccionario_dataframe, index=[0])], ignore_index=True)
  return full_df, df

# %%
dfFull = pd.DataFrame()
for file in files_suelos:
  dfFull, df_suplementario = readFormato(file, dfFull)
  
dfFull
# Out:
#    Clave del Proyecto:                           Localidad, Mpio. y Edo.:  \
# 0        TOXI - 321542                                      Armería, Col.
# 1        TOXI - 321542                                      Armería, Col.
# 2          TOXI-321542                                             Colima
# 3          TOXI-321542                                             Colima
# 4          TOXI-321542                                    Colima, Colima.
# 5          TOXI-321542                                             Colima
# 6          TOXI-321542                                             Colima
# 7          TOXI-321542                                             Colima
# 8          TOXI-321542                                             Colima
# 9                  NaN                                                NaN
# 10         TOXI-321542                                 Minatitlán, Colima
# 11         TOXI-321542                                Minatitlán, Colima.
# 12         TOXI-321542                    El Poblaso, Minatitlán, Colima.
# 13         TOXI-321542                  Las Guasimas, Minatitlán, Colima.
# 14         TOXI-321542                                  Nogueras, Colima.
# 15         TOXI-321542                                  Quesería, Colima.
# 16         TOXI-321542                                  Quesería, Colima.
# 17         TOXI-321542                                  Quesería, Colima.
# 18         TOXI-321542                                  Quesería, Colima.
# 19         TOXI-321542                                  Quesería, Colima.
# 20         TOXI-321542                                  Quesería, Colima.
# 21         TOXI-321542  El Mameyito de Peña colorada, Villa de Álvrez,...
# 22         TOXI-321542                           Villa de Álvrez, Colima.
# 23         TOXI-321542                           Villa de Álvrez, Colima.
# 24         TOXI-321542                           Villa de Álvrez, Colima.
# 25       TOXI - 321542                                   Manzanillo, Col.
# 26       TOXI - 321542                                   Manzanillo, Col.
# 27       TOXI - 321542                                   Manzanillo, Col.
# 28       TOXI - 321542                                   Manzanillo, Col.
# 29       TOXI - 321542                                   Manzanillo, Col.
# 30       TOXI - 321542                                   Manzanillo, Col.
# 31       TOXI - 321542                                   Manzanillo, Col.
# 32       TOXI - 321542                                   Manzanillo, Col.
# 33       TOXI - 321542                            Alzada, Cuauhtemoc,Col.
# 34       TOXI - 321542                            Alzada, Cuauhtemoc,Col.
# 35       TOXI - 321542                                   Manzanillo, Col.
# 36       TOXI - 321542                                   Manzanillo, Col.
# 37       TOXI - 321542                                   Manzanillo, Col.
# 38       TOXI - 321542                                   Manzanillo, Col.
# 39       TOXI - 321542                                   Manzanillo, Col.
# 40       TOXI - 321542                                   Manzanillo, Col.
# 41       TOXI - 321542                           Canoas, Manzanillo, Col.
# 42       TOXI - 321542                         Tecomán, camino a Caleras
# 43       TOXI - 321542                                      Tecomán, Col.
# 44       TOXI - 321542                                       Tecomán, Col
# 45       TOXI - 321542                                      Tecomán, Col.
# 46       TOXI - 321542                                      Tecomán, Col.
# 47       TOXI - 321542                                      Tecomán, Col.
# 48       TOXI - 321542                                      Tecomán, Col.
# 49       TOXI - 321542                                      Tecomán, Col.
# 50       TOXI - 321542                                      Tecomán, Col.
# 51       TOXI - 321542                                      Tecomán, Col.
#
#    Clave de la muestra:               Fecha: Tipo de muestreo:    UTM hor.:  \
# 0            EVP-SS- 05  2022-10-13 00:00:00           Simple     606251.00
# 1            EPV-SS- 01  2022-10-13 00:00:00           Simple     602079.00
# 2              COL-SS-1  2022-10-11 00:00:00            Simple    636080.00
# 3              COL-SS-3  2022-10-11 00:00:00            Simple    637535.00
# 4              COL-SS-5  2022-10-11 00:00:00            Simple    630907.00
# 5              COL-SS-8  2022-10-11 00:00:00            Simple    633189.82
# 6             COL-SS-10  2022-10-11 00:00:00            Simple     63742.00
# 7             COL-SS-11  2022-10-11 00:00:00            Simple    633984.00
# 8             COL-SS-12  2022-10-11 00:00:00            Simple    635423.00
# 9                   NaN                  NaT               NaN          NaN
# 10            MIN-SS-02  2022-10-15 00:00:00            Simple    599132.00
# 11            MIN-SS-03  2022-10-15 00:00:00            Simple    600174.00
# 12            MIN-SS-05  2022-10-15 00:00:00            Simple    595020.00
# 13            MIN-SS-06  2022-10-15 00:00:00            Simple    598200.00
# 14            NOG-SS-01  2022-10-14 00:00:00            Simple    632342.00
# 15              Q-SS-01  2022-10-14 00:00:00            Simple    649297.00
# 16              Q-SS-02  2022-10-14 00:00:00            Simple    649872.00
# 17              Q-SS-03  2022-10-14 00:00:00            Simple    650031.00
# 18              Q-SS-04  2022-10-14 00:00:00            Simple    650567.00
# 19              Q-SS-05  2022-10-14 00:00:00            Simple    649008.00
# 20              Q-SS-06  2022-10-14 00:00:00            Simple    649613.00
# 21            VA-SS-01A  2022-10-15 00:00:00            Simple          NaN
# 22              VA-SS-6  2022-10-11 00:00:00            Simple    632461.00
# 23              VA-SS-7  2022-10-11 00:00:00            Simple    630647.80
# 24              VA-SS-9  2022-10-11 00:00:00            Simple    633192.00
# 25             MZ-SS-06  2022-10-16 00:00:00           Simple     570449.22
# 26             MZ-SS-10  2022-10-16 00:00:00           Simple     575198.36
# 27             MZ-SS-11  2022-10-16 00:00:00           Simple     571258.22
# 28             MZ-SS-12  2022-10-16 00:00:00           Simple     573217.77
# 29             MZ-SS-14  2022-10-16 00:00:00           Simple     575822.23
# 30             MZ-SS-15  2022-10-16 00:00:00           Simple     574626.06
# 31             MZ-SS-18  2022-10-16 00:00:00           Simple     573102.03
# 32             MZ-SS-15  2022-10-16 00:00:00           Simple     575743.29
# 33            ALZ-SS-01  2022-10-14 00:00:00           Simple           NaN
# 34            ALZ-SS-01  2022-10-14 00:00:00           Simple     684477.00
# 35             MZ-SS-01  2022-10-12 00:00:00           Simple   57115535.00
# 36             MZ-SS-4B  2022-10-12 00:00:00           Simple     569687.22
# 37             MZ-SS-09  2022-10-12 00:00:00           Simple     572444.49
# 38             MZ-SS-11  2022-10-12 00:00:00           Simple     571269.23
# 39             MZ-SS-16  2022-10-12 00:00:00           Simple     572444.49
# 40             MZ-SS-17  2022-10-12 00:00:00           Simple   57115535.00
# 41            CAN-SS-01  2022-10-15 00:00:00           Simple     589093.00
# 42            TEC-SS-01          13/0ct/2022            Simple    618792.00
# 43            TEC-SS-02  2022-10-13 00:00:00      Superficial     616997.00
# 44            TEC-SS-03  2022-10-13 00:00:00           Simple     616997.00
# 45            TEC-SS-04  2022-10-13 00:00:00           Simple     619103.00
# 46            TEC-SS-05  2022-10-13 00:00:00           Simple     616897.00
# 47            TEC-SS-07  2022-10-13 00:00:00            Simple    620967.00
# 48            TEC-SS-08  2022-10-13 00:00:00           Simple     622735.00
# 49            TEC-SS-09  2022-10-13 00:00:00           Simple     618120.00
# 50            TEC-SS-10  2022-10-13 00:00:00           Simple     618058.00
# 51            TEC-SS-11  2022-10-13 00:00:00           Simple     608481.00
#
#    Hora de inicio (hh:mm):     Tipo de muestra:   UTM ver.:    msnm:  \
# 0                  10:21:00  Suelo superficial   2087489.00     2.00
# 1                       NaN  Suelo superficial   2091443.00    14.00
# 2                  14:07:00   Suelo superficial  2131759.00   601.00
# 3                  12:50:00   Suelo superficial  2127070.00   518.00
# 4                  19:30:00   Suelo superficial  2127986.00   468.00
# 5                  11:00:00   Suelo superficial  2125196.15   448.00
# 6                  13:28:00   Suelo superficial  2128941.00   576.00
# 7                  18:02:00   Suelo superficial  2129189.00   508.00
# 8                  12:05:00   Suelo superficial  2126192.00   463.00
# 9                       NaN                 NaN         NaN      NaN
# 10                      NaN   Suelo superficial  2144984.00   725.00
# 11                 19:15:00   Suelo superficial  2144395.00   736.00
# 12                 17:45:00   Suelo superficial  2141170.00   683.00
# 13                 18:40:00   Suelo superficial  2140378.00   689.00
# 14                 12:00:00   Suelo superficial  2137113.00      NaN
# 15                 14:20:00   Suelo superficial  2144870.00  1301.00
# 16                      NaN   Suelo superficial  2144307.00  1265.00
# 17                 15:10:00   Suelo superficial  2143841.00  1216.00
# 18                 15:35:00   Suelo superficial  2144274.00  1231.00
# 19                 13:15:00   Suelo superficial  2144302.00  1269.00
# 20                 13:50:00   Suelo superficial  2143896.00  1243.00
# 21                 12:00:00  Suelo superficial.         NaN   589.00
# 22                 17:23:00  Suelo superficial.       21.00   538.00
# 23                 15:43:00  Suelo superficial.  2130841.03   525.00
# 24                 15:15:00  Suelo superficial.  2133485.00   616.00
# 25                 15:28:00  Suelo superficial   2114701.58    17.40
# 26                 11:33:00  Suelo superficial   2110745.00    19.53
# 27                 16:20:00  Suelo superficial   2113515.37     9.77
# 28                 09:20:00  Suelo superficial          NaN     9.16
# 29                 10:46:00  Suelo superficial   2108311.71    90.34
# 30                 10:05:00  Suelo superficial   2107243.80    20.14
# 31                 12:04:00  Suelo superficial   2112190.44    10.08
# 32                 13:07:00  Suelo superficial   2112549.21    36.52
# 33                 16:24:00  Suelo superficial          NaN   671.00
# 34                 15:05:00  Suelo superficial   2130095.00      NaN
# 35                 00:41:00  Suelo superficial   2103545.86      NaN
# 36                 14:43:00  Suelo superficial   2112844.91     8.00
# 37                 00:09:00  Suelo superficial   2103585.62     6.00
# 38            03:16:00 p.m.  Suelo superficial   2113005.45     9.00
# 39                 00:09:00  Suelo superficial   2103585.62     6.00
# 40                 11:14:00  Suelo superficial   2103545.86     5.00
# 41                 16:45:00  Suelo superficial   2129209.00   529.00
# 42                 18:44 pm  Suelo superficial   2099659.00    86.00
# 43                 13:55:00  Suelo Superficial   2093272.00    68.00
# 44                 13:16:00  Suelo superficial   2093272.00    63.00
# 45                 14:28:00  Suelo superficial   2091339.00    52.00
# 46                 15:55:00   Suelo superficial  2089151.00    41.00
# 47                 14:55:00  Suelo superficial   2087421.00    43.00
# 48                 15:13:00  Suelo superficial   2086354.00    28.00
# 49                 19:25:00  Suelo superficial   2160505.00    73.00
# 50                 19:04:00  Suelo superficial   2100904.00    77.00
# 51                 12:19:00  Suelo superficial   2094314.00    46.00
#
#     Condiciones climáticas:                            Uso de suelo:  \
# 0                 Despejado                   Urbano acceso a estero
# 1                 Despejado                     Parcela en descanso
# 2   Cielo despejado, 32° C.                                   Urbano
# 3    Cielo despejado, 30°C.                     Recreativo (escuela)
# 4                   Nublado                        Agricola inactiva
# 5           Cielo despejado               Suelo de cultivo en desuso
# 6    Cielo despejado, 30°C.           Recreativo (esciela primaria).
# 7      Cielo nublado, 30°C.                               Recreativo
# 8    Cielo despejado, 30°C.                         Escuela primaria
# 9                       NaN                                      NaN
# 10                      NaN                              Vía pública
# 11              Seminublado                               Recreativo
# 12                  Nublado                    Vialidad a un costado
# 13                    Bruma                              Vía pública
# 14                Despejado                                      NaN
# 15     Seminublado con sol.                           Solar, cercado
# 16      Seminublado con sol                              Comunitario
# 17              Seminublado                 Zona recreativa infantil
# 18      Seminublado con sol            Recreativo en desuso (cancha)
# 19           Soleado, bruma                                      NaN
# 20    Parcialmente nublado.                                  Escuela
# 21                Despejado                                Agrícola
# 22   Cielo despejado, 30°C.                                   Urbano
# 23   Cielo despejado, 32°C.            Recreativo / parque infantil.
# 24   Cielo despejado, 32°C.                              Comunitaria
# 25                 Soleado                       Rancho / sembradío
# 26                 Soleado                 periferia campo de fútbol
# 27                 Soleado                                    Baldío
# 28                 Nublado                                  Terreno
# 29                 Soleado   Banco de materiales/ Patio de trailers
# 30                 Soleado                           Terreno baldío
# 31                 Soleado                                   Parque
# 32                 Soleado                                 Ranchería
# 33                Despejado                       Orilla vía federal
# 34             Semi nublado                                   Solar
# 35         Nublado/ soleado                             Reacreativo
# 36             Soleado 32°C                                 Forestal
# 37               Nublado 29                             Reacreativo
# 38                  Soleado                             Reacreativo
# 39             Nublado 29°C                   Reacreativo ( Escuela)
# 40                 Nublado                         Área reacreativa
# 41           Lluvia ligera                                       NaN
# 42               Despejado                                       NaN
# 43               Despejado                         Escuela primaria
# 44                Despejado                         Área recreativa
# 45               Despejado                       Escuela abandonada
# 46               Despejado                                   Predio
# 47               Despejado                           Parcela sin uso
# 48      Soleado, despejado                                Recreativo
# 49               Despejado                                Recreativo
# 50               Despejado                                   Parque
# 51      Soleado, despejado             Actividad ganadera (pastoreo)
#
#                                   Tipo de vegetación:  \
# 0                                              Pasto
# 1                                                 NaN
# 2                      Pastizal y matorral arbustivo.
# 3                                             Árboles
# 4                                   Rectangular plano
# 5                   Secundaria, selva baja, matorral.
# 6                                  Árboles de ornato.
# 7                                  Árboles de ornato.
# 8                                           De ornato
# 9                                                 NaN
# 10                                                NaN
# 11                                              Pasto
# 12                                            Árboles
# 13                            Secundaria, higuerilla.
# 14                      Pasto, vegetación ornamental.
# 15                                         Secundaria
# 16                              Árboles de ornamiento
# 17                              Pasto seco y árboles.
# 18                                                NaN
# 19                                 Mango, sauz, nance
# 20                      Secundaria, árboles frutales.
# 21                         Milpa, vegetación primaria
# 22                                              Pasto
# 23                             Pasto natural (cesped)
# 24                                    Pasto doméstico
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                    Sin vegetación
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                           Árboles
# 34                                   Ornato y frutal
# 35                                       Cesped corto
# 36                                           Árboles
# 37                                       Césped corto
# 38                                  Cesped / Árboles
# 39                                           Árboles
# 40                                      Cesped corto
# 41  Rosa morada, presencia de algúnos árboles poca...
# 42                             Vegetación secundaria
# 43                                         Ornamental
# 44                              Árboles ornamentales
# 45                                        Secundaria
# 46                                          Pastizal
# 47                               Palmeras y pastizal
# 48                       Pasto, árboles de Guamuchil.
# 49                                    Parota, platano
# 50                                             Pasto.
# 51                                        Secundaria.
#
#                    Edificación o infraestructura:  \
# 0                                  Costado de lab
# 1                                Sin edificación
# 2                                          Baldío
# 3                                Escuela primaria
# 4                                Parcela inactiva
# 5                                Cerca de alambre
# 6                     Chanchas y patio de juegos.
# 7                                    Áreas verdes
# 8                                         Escuela
# 9                                             NaN
# 10                                            NaN
# 11                      Exterior, cancha, juegos.
# 12                                            NaN
# 13  Parque baldío, 50 m entrada rancho la Higuera
# 14                                            NaN
# 15                                            NaN
# 16                               Jardín principal
# 17                               Patio recreativo
# 18                                         Cancha
# 19                                            NaN
# 20              Salones de clase, patios, cancha.
# 21                                Zonas de milpas
# 22                          Zona deportiva (pozo)
# 23                              Juegos infaniles.
# 24         Atrio de de parroquia en construcción.
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
# 33                             Ext. Peletizadora
# 34                  Solar, aledaño a peletizadora
# 35                            Escuela secuendaria
# 36                            Terreno con plantas
# 37                                  Campo de golf
# 38                                        Parque
# 39                               Escuela primaria
# 40                              Escuela primaria
# 41                             Escuela preescolar
# 42                              Orilla carretera
# 43                       Escuela primaria Federal
# 44                           Zona urbana (Parque)
# 45                              Predio abandonado
# 46                Espacio entre carretera estatal
# 47                             Cercano a zona de
# 48                          Cancha futbol rápido
# 49                          Cancha futbol rápido
# 50                     Rodeado de casas habitadas
# 51                         Colinda con domicilio
#
#                  Forma del terreno:       Inclinación: Evidencia de erosión:  \
# 0                      Rectangular            Planicie                   No
# 1                      Rectangular            Planicie                   No
# 2                             Plano                NaN                    No
# 3                             Plano                NaN                    No
# 4                               NaN           Planicia                    NO
# 5     Predio rectangular, arbustivo                NaN                    No
# 6                             Plano                NaN                    No
# 7                          Planicie                NaN             No aplica
# 8                             Plano                NaN                    No
# 9                               NaN                NaN                   NaN
# 10                              NaN                NaN                   NaN
# 11                              NaN          Pendiente                    No
# 12                Orilla del camino          Pendiente                    No
# 13                              NaN          Pendiente                    No
# 14                              NaN                NaN                   NaN
# 15                      Rectangular          Pendiente                    No
# 16                         Cuadrado           Planicie                    No
# 17                      Rectangular          Pendiente                    No
# 18                      Rectangular           Planicie                    No
# 19                        Pendiente          Pendiente                    No
# 20                      Rectangular          Pendiente                    No
# 21                        Escarpado          Pendiente                    No
# 22                            Plano                NaN                    No
# 23                            Plano               Nula                    No
# 24       Pendiente poco pronunciada                NaN     Suelo semidesnudo
# 25                              NaN                NaN                   NaN
# 26                              NaN                NaN                   NaN
# 27                              NaN                NaN                   NaN
# 28                           Plano                  0°                   NaN
# 29                              NaN                NaN                   NaN
# 30                              NaN                NaN                   NaN
# 31                              NaN                NaN                   NaN
# 32                              NaN                NaN                   NaN
# 33                            Plano  Ligera pendiente                    No
# 34                      Rectangular          Planicie                    No
# 35                            Plano                NaN                   No
# 36                            Plano                NaN                   No
# 37                Pendiente mínima                 NaN                   No
# 38                            Plano                NaN                   No
# 39                            Plano                NaN                   No
# 40                            Plano                NaN                   No
# 41                     Rectangular          Pendiente                    No
# 42                Meseta/ carretera          Pendiente                    No
# 43                         Escuadra           Planicie                    No
# 44                  Parque cuadrado         Horizontal                    No
# 45                         Cuadrado          Planicie                     No
# 46                     Rectangular           Planicie                     No
# 47                        Cuadrado            Planicie                    No
# 48                      Rectangular          Planicie                     No
# 49  Rectangular a orilla de cancha           Planicie                     No
# 50                      Rectangular          Planicie                     No
# 51                      Rectangular                NaN                    No
#
#                                              Paisaje:  \
# 0                         Cobertura vegetal mantillo.
# 1                                                 NaN
# 2                      Vejetación secundaria, urbano.
# 3                                              Urbano
# 4                                           Suburbano
# 5                                                 NaN
# 6                                              Urbano
# 7                                              Urbano
# 8                                              Urbano
# 9                                                 NaN
# 10                                                NaN
# 11                           Urbano, zona recreativa.
# 12                           Orilla, camino empedrado
# 13                            Rural, camino artesanal
# 14                                                NaN
# 15                                        Zona urbana
# 16                                             Urbano
# 17                                             Urbano
# 18                             Urbano, aledaño a carr
# 19                                  Zona habitacional
# 20                     Urbano con calles pavimetadas.
# 21       Ubicado en ladera en pendiente entre cerros.
# 22                 Zona urbana, vegetación arbustiva.
# 23  Ornato y alrededor pastizal o vegetación secud...
# 24                                             Urbano
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                             Exterior paletizadora
# 34                                 Habitacional rural
# 35                                            Urbano
# 36                                            Urbano
# 37                                            Urbano
# 38                                            Urbano
# 39                                            Urbano
# 40                                            Urbano
# 41                      Rural, calles sin pavimentar
# 42                             Cercano a horno Holcim
# 43                                     Patio escolar
# 44                                                NaN
# 45                 Escuela abandonada en zona urbana.
# 46               pastizal y al fondo árboles de mango
# 47  Zona rural cercada de cultivos papayo, cocoter...
# 48                                   Camino empedrado
# 49               Cancha de fut a orilla de carretera.
# 50                                 Parque recreativo.
# 51                                           Paisaje.
#
#                    Tipo de suelo: Material parental:
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                         Desnudo          Pendiente
# 4                             NaN                NaN
# 5                             NaN                NaN
# 6                             NaN          Pendiente
# 7   Urbano (recreativo) infantil.                NaN
# 8                             NaN          Pendiente
# 9                             NaN                NaN
# 10                            NaN                NaN
# 11                            NaN                NaN
# 12                            NaN                NaN
# 13                            NaN                NaN
# 14                            NaN                NaN
# 15                            NaN                NaN
# 16                            NaN                NaN
# 17                            NaN                NaN
# 18                            NaN                NaN
# 19                            NaN                NaN
# 20                            NaN                NaN
# 21                            NaN                NaN
# 22                         Urbano                NaN
# 23  Recreativo (parque infantil).                NaN
# 24                         Urbano                NaN
# 25                      Arcilloso                NaN
# 26                      Arcilloso                NaN
# 27           Arenoso con piedras                 NaN
# 28                     Arcilloso                 NaN
# 29                         Rocoso                NaN
# 30                            NaN                NaN
# 31                        Arenoso                NaN
# 32                            NaN                NaN
# 33                            NaN                NaN
# 34                          Solar                No
# 35                        Desnudo         Pendiente
# 36                 Terreno baldío         Pendiente
# 37         Urbano (Campo de golf)         Pendiente
# 38                        Parque          Pendiente
# 39                        Desnudo         Pendiente
# 40                        Desnudo         Pendiente
# 41                            NaN         Pendiente
# 42                            NaN                NaN
# 43                             No                 No
# 44                            NaN                No
# 45                            NaN                NaN
# 46                            NaN                 No
# 47                            NaN                NaN
# 48                            NaN                NaN
# 49                            NaN                NaN
# 50                            NaN                NaN
# 51                            NaN                NaN

# %%
df_suplementario
# Out:
#                                            Unnamed: 0 Unnamed: 1  \
# 1                                                 NaN        NaT
# 6                                                 NaN        NaT
# 7     Registro de levantamiento de muestras de suelo         NaT
# 9                                     DATOS GENERALES        NaT
# 10                                Clave del Proyecto:        NaT
# 11                           Localidad, Mpio. y Edo.:        NaT
# 12  Nombre de la(s) persona(s) que participan:    ...        NaT
# 14                                             Fecha: 2022-10-13
# 15                           Hora de inicio (hh:mm):         NaT
# 16                         Hora de término (hh:mm):          NaT
# 18                       DESCRIPCIÓN FÍSICA DEL SITIO        NaT
# 19                            Condiciones climáticas:        NaT
# 20                                Tipo de vegetación:        NaT
# 21                                 Forma del terreno:        NaT
# 22                                     Tipo de suelo:        NaT
# 23                                           Paisaje:        NaT
# 24  Observaciones: Aledaño a zona habitcional y ca...        NaT
# 27                                        FOTOGRAFÍAS        NaT
# 29                      Paisaje del sitio de muestreo        NaT
# 31                           Responsable del muestreo        NaT
# 32                                            Nombre:        NaT
# 33                                             Firma:        NaT
#
#              Unnamed: 3          Unnamed: 5                    Unnamed: 7  \
# 1                   NaN                 NaN                           NaN
# 6                   NaN                 NaN                           NaN
# 7                   NaN                 NaN                           NaN
# 9                   NaN                 NaN                           NaN
# 10        TOXI - 321542                 NaN                           NaN
# 11        Tecomán, Col.                 NaN                           NaN
# 12                  NaN                 NaN                           NaN
# 14                  NaN   Tipo de muestreo:                       Simple
# 15             12:19:00    Tipo de muestra:            Suelo superficial
# 16             12:46:00  Refrigeración:       Sí__X___            No_____
# 18                  NaN                 NaN                           NaN
# 19  Soleado, despejado                  NaN                           NaN
# 20          Secundaria.                 NaN                           NaN
# 21          Rectangular                 NaN                           NaN
# 22                  NaN                 NaN                           NaN
# 23             Paisaje.                 NaN                           NaN
# 24                  NaN                 NaN                           NaN
# 27                  NaN                 NaN                           NaN
# 29                  NaN                 NaN                           NaN
# 31                  NaN                 NaN                           NaN
# 32                  NaN                 NaN                           NaN
# 33                  NaN                 NaN                           NaN
#
#                         Unnamed: 8  \
# 1                              NaN
# 6                              NaN
# 7                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 18                             NaN
# 19                   Uso de suelo:
# 20  Edificación o infraestructura:
# 21                    Inclinación:
# 22           Evidencia de erosión:
# 23              Material parental:
# 24                             NaN
# 27                             NaN
# 29                 Toma de muestra
# 31               Revisó y Autorizó
# 32                        Nombre:
# 33                          Firma:
#
#                                            Unnamed: 9           Unnamed: 10  \
# 1   PERFIL EPIDEMIO-TOXICOLÓGICO PARA DEFINIR UNA...                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN  Clave de la muestra:
# 11                                                NaN             TEC-SS-11
# 12                                                NaN                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 27                                                NaN                   NaN
# 29                                                NaN                   NaN
# 31                                                NaN                   NaN
# 32                                                NaN                   NaN
# 33                                                NaN                   NaN
#
#                       Unnamed: 12  Unnamed: 13           Unnamed: 20
# 1                             NaN          NaN                   NaN
# 6                             NaN          NaN  ajustar a una página
# 7                             NaN          NaN                   NaN
# 9                             NaN          NaN                   NaN
# 10                            NaN          NaN                   NaN
# 11                            NaN          NaN                   NaN
# 12                            NaN          NaN                   NaN
# 14                      UTM hor.:     608481.0                   NaN
# 15                      UTM ver.:    2094314.0                   NaN
# 16                          msnm:         46.0                   NaN
# 18                            NaN          NaN                   NaN
# 19  Actividad ganadera (pastoreo)          NaN                   NaN
# 20         Colinda con domicilio           NaN                   NaN
# 21                            NaN          NaN                   NaN
# 22                             No          NaN                   NaN
# 23                            NaN          NaN                   NaN
# 24                            NaN          NaN                   NaN
# 27                            NaN          NaN                   NaN
# 29                            NaN          NaN                   NaN
# 31                            NaN          NaN                   NaN
# 32                            NaN          NaN                   NaN
# 33                            NaN          NaN                   NaN

# %%
# df_suplementario to array
df_suplementario = df_suplementario.values

df_suplementario
# Out:
# array([[nan, NaT, nan, nan, nan, nan,
#         'PERFIL EPIDEMIO-TOXICOLÓGICO PARA DEFINIR UNA REGIÓN DE EMERGENCIA SOCIO-AMBIENTAL Y SANITARIA EN EL ESTADO DE COLIMA     Py CONACyT 321542',
#         nan, nan, nan, nan],
#        [nan, NaT, nan, nan, nan, nan, nan, nan, nan, nan,
#         'ajustar a una página'],
#        ['Registro de levantamiento de muestras de suelo ', NaT, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan],
#        ['DATOS GENERALES', NaT, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan],
#        ['Clave del Proyecto:', NaT, 'TOXI - 321542', nan, nan, nan, nan,
#         'Clave de la muestra:', nan, nan, nan],
#        ['Localidad, Mpio. y Edo.:', NaT, 'Tecomán, Col.', nan, nan, nan,
#         nan, 'TEC-SS-11', nan, nan, nan],
#        ['Nombre de la(s) persona(s) que participan:    Elias,Cesar y Chava',
#         NaT, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        ['Fecha:', Timestamp('2022-10-13 00:00:00'), nan,
#         'Tipo de muestreo:', 'Simple ', nan, nan, nan, 'UTM hor.:',
#         608481.0, nan],
#        ['Hora de inicio (hh:mm): ', NaT, datetime.time(12, 19),
#         'Tipo de muestra:', 'Suelo superficial ', nan, nan, nan,
#         'UTM ver.:', 2094314.0, nan],
#        ['Hora de término (hh:mm):  ', NaT, datetime.time(12, 46),
#         'Refrigeración:    ', ' Sí__X___            No_____', nan, nan,
#         nan, 'msnm:', 46.0, nan],
#        ['DESCRIPCIÓN FÍSICA DEL SITIO', NaT, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        ['Condiciones climáticas:', NaT, 'Soleado, despejado ', nan, nan,
#         'Uso de suelo:', nan, nan, 'Actividad ganadera (pastoreo)', nan,
#         nan],
#        ['Tipo de vegetación:', NaT, 'Secundaria.', nan, nan,
#         'Edificación o infraestructura:', nan, nan,
#         'Colinda con domicilio ', nan, nan],
#        ['Forma del terreno:', NaT, 'Rectangular', nan, nan,
#         'Inclinación:', nan, nan, nan, nan, nan],
#        ['Tipo de suelo:', NaT, nan, nan, nan, 'Evidencia de erosión:',
#         nan, nan, 'No', nan, nan],
#        ['Paisaje:', NaT, 'Paisaje.', nan, nan, 'Material parental:', nan,
#         nan, nan, nan, nan],
#        ['Observaciones: Aledaño a zona habitcional y calle trafico. Vegetación secuendaria.',
#         NaT, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        ['FOTOGRAFÍAS', NaT, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        ['Paisaje del sitio de muestreo', NaT, nan, nan, nan,
#         'Toma de muestra', nan, nan, nan, nan, nan],
#        ['Responsable del muestreo', NaT, nan, nan, nan,
#         'Revisó y Autorizó', nan, nan, nan, nan, nan],
#        ['Nombre:', NaT, nan, nan, nan, 'Nombre: ', nan, nan, nan, nan,
#         nan],
#        ['Firma:', NaT, nan, nan, nan, 'Firma:', nan, nan, nan, nan, nan]],
#       dtype=object)

# %%
df_suplementario
